# %%
import sys
import folium
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from folium.plugins import HeatMap

df = pd.read_csv('../data/trip_path_mbike_start_20190114.csv')
print("DF size is " + str(len(df.index)))
df.head(5)
# Out:
# DF size is 1851924
#    Coords_Latitude  Coords_Longitude            Trip_ID  \
# 0        38.978141        -76.928956  Hf3aj78RcGaJJMGRn
# 1        38.978200        -76.928471  tp7QKuiJX9DvLKDcf
# 2        38.972647        -76.938315  tp7QKuiJX9DvLKDcf
# 3        38.978369        -76.928679  j7xEWoy65rDsJfk7M
# 4        38.972581        -76.938422  j7xEWoy65rDsJfk7M
#
#               Bike_Event            User_ID                 Date_Time
# 0              StartTrip  24Tswou857XKT9R65  2017-06-14T19:02:21.593Z
# 1              StartTrip  24Tswou857XKT9R65  2017-06-15T20:07:14.437Z
# 2  EndTripInsideGeofence  24Tswou857XKT9R65  2017-06-15T20:19:43.891Z
# 3              StartTrip  24Tswou857XKT9R65  2017-06-17T22:25:55.592Z
# 4  EndTripInsideGeofence  24Tswou857XKT9R65  2017-06-17T22:36:07.021Z

# %%
dfBgdOnly = df[df['Bike_Event'] == 'Background']
n = len(dfBgdOnly.Trip_ID)
dfBgdOnly.Trip_ID.value_counts().describe()
# Out:
# count    45272.000000
# mean        27.957347
# std         78.273398
# min          1.000000
# 25%          4.000000
# 50%         16.000000
# 75%         32.000000
# max      10601.000000
# Name: Trip_ID, dtype: float64

# %%
dfx = df[(df['Bike_Event'] != 'Background') & (df['Bike_Event'] != 'Foreground')]
dfx = dfx[(dfx['Bike_Event'] != 'EndTripGeofenceDisabled') & (dfx['Bike_Event'] != 'AccessCodeBLEFallback')]
dfx = dfx[(dfx['Bike_Event'] != 'SentrilockAccessCodeShown') & (dfx['Bike_Event'] != 'OnHold')]
#colss = [i[:] for i in dfx.columns]
#dfx.columns = colss
sns.countplot(dfx.Bike_Event)
dfx.Bike_Event.value_counts()
# Out:
# StartTrip                   77718
# AttemptLock                 75120
# Unlock                      59150
# EndTripInsideGeofence       58735
# AccessCode                  58131
# Lock                        51688
# AttemptUnlock               26344
# KeypadAccessCodeShown       12687
# EndTripStoppedByGeofence    10931
# EndTripBypassGeofence       10093
# Name: Bike_Event, dtype: int64

# %%
df = df[(df['Bike_Event'] == 'StartTrip') | (df['Bike_Event'] == 'EndTripInsideGeofence')]
print("Only %s are Start/End trip events." % str(len(df.index)))

dfStart = df[df['Bike_Event'] == 'StartTrip']
dfEnd = df[df['Bike_Event'] == 'EndTripInsideGeofence']
df[df['Trip_ID']== 'L3QADAJtdmgLdenDj']
#print(df[df['Trip_ID'] == 'L3QADAJtdmgLdenDj'])
# Out:
# Only 136453 are Start/End trip events.
#        Coords_Latitude  Coords_Longitude            Trip_ID  \
# 54191        38.992974        -76.937454  L3QADAJtdmgLdenDj
# 54194        38.993227        -76.941564  L3QADAJtdmgLdenDj
# 54195        38.993227        -76.941564  L3QADAJtdmgLdenDj
# 54196        38.993227        -76.941564  L3QADAJtdmgLdenDj
# 54197        38.993227        -76.941564  L3QADAJtdmgLdenDj
# 54198        38.993227        -76.941564  L3QADAJtdmgLdenDj
# 54199        38.993227        -76.941564  L3QADAJtdmgLdenDj
# 54200        38.993227        -76.941564  L3QADAJtdmgLdenDj
# 54201        38.993227        -76.941564  L3QADAJtdmgLdenDj
# 54202        38.993227        -76.941564  L3QADAJtdmgLdenDj
#
#                   Bike_Event            User_ID                 Date_Time
# 54191              StartTrip  36xxpQuhZWX7oAwdD  2017-07-20T13:46:48.005Z
# 54194  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.494Z
# 54195  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.529Z
# 54196  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.531Z
# 54197  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.573Z
# 54198  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.598Z
# 54199  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.601Z
# 54200  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.603Z
# 54201  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.688Z
# 54202  EndTripInsideGeofence  36xxpQuhZWX7oAwdD  2017-07-20T14:35:43.691Z

# %%
dfz = df.copy()
dfz['Coords_Latitude'] = dfz['Coords_Latitude'].astype('float')
dfz['Coords_Longitude'] = dfz['Coords_Longitude'].astype('float')
print("Range Latitutde: " + str(dfz['Coords_Latitude'].max() - dfz['Coords_Latitude'].min()))
print("Range Longonitude: " + str(dfz['Coords_Longitude'].max() - dfz['Coords_Longitude'].min()))
print(dfz['Coords_Longitude'].max(), dfz['Coords_Longitude'].min())
print(dfz['Coords_Latitude'].max(), dfz['Coords_Latitude'].min())
print("Variance: " + str(dfz['Coords_Longitude'].var()))
# Out:
# Range Latitutde: 3.62778724154537
# Range Longonitude: 243.934875
# 126.934875 -117.0
# 39.713754941545375 36.085967700000005
# Variance: 0.9574997201921622

# %% [markdown]
# # Clean Data
# Clearly something is wrong with our data, since a Longitude of 126 is on the other side of the earth.
# So, we're going to pick opposite corners of a square to define College Park and its surrounding region, and remove anything outside of this. We'll remove all events outside of the box made by these corners.

# %%
# (Botoom right corner - East riverdale/highway) [BR]
# (Top Left corner - Adelphi) [TL] 
LatTL, LongTL = [38.998028, -76.962679]
LatBR, LongBR = [38.953989,-76.906056]
dfz = dfz[(dfz['Coords_Latitude'] <= LatTL) & (dfz['Coords_Latitude'] >= LatBR)]
dfz = dfz[(dfz['Coords_Longitude'] >= LongTL) & (dfz['Coords_Longitude'] <= LongBR)]
#Check the min/max to make sure they're reasonable now:
print(dfz['Coords_Longitude'].min(), dfz['Coords_Latitude'].max())
# Out:
# -76.96218583365523 38.9980096

# %%
g = sns.jointplot("Coords_Longitude", "Coords_Latitude", data=dfz[dfz['Bike_Event']=='StartTrip'], xlim=[-76.955, -76.920], ylim=[38.97,39],kind="hex",joint_kws=dict(gridsize=35))

# %% [markdown]
# *This shows usage by binning lat, longitude into hexagons. The darker the hexagon, the higher the sum of all start & end trip events that occured in that bin.*  (Start Trip)

# %%
g = sns.jointplot("Coords_Longitude", "Coords_Latitude", data=dfz[dfz['Bike_Event']=='EndTripInsideGeofence'], xlim=[-76.955, -76.920], ylim=[38.97,39], kind='hex', joint_kws= dict(gridsize=35))

# %% [markdown]
# *This shows usage by binning lat, longitude into hexagons. The darker the hexagon, the higher the sum of all start & end trip events that occured in that bin.*  (End Trip)

# %%
def embed_map(m):
    from IPython.display import IFrame

    m.save('index.html')
    return IFrame('index.html', width='100%', height='750px')
map_CP = folium.Map(location=[dfz.Coords_Latitude.mean(), dfz.Coords_Longitude.mean()], zoom_start=15)
mc = folium.plugins.MarkerCluster()

for i in range (0,5000):
    lat = dfz.Coords_Latitude.iloc[i]
    long = dfz.Coords_Longitude.iloc[i]
    mc.add_child(folium.Marker([lat,long]))#.add_to(map_CP)

map_CP.add_child(mc)
embed_map(map_CP)
# Out:
#         <iframe
#             width="100%"
#             height="750px"
#             src="index.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
map_CP = folium.Map(location=[dfz.Coords_Latitude.mean(), dfz.Coords_Longitude.mean()], zoom_start=15)
mc = folium.plugins.MarkerCluster()
dfSample = dfz.sample(10000)
for i in range (0,10000):
    lat = dfSample.Coords_Latitude.iloc[i]
    long = dfSample.Coords_Longitude.iloc[i]
    mc.add_child(folium.Marker([lat,long]))#.add_to(map_CP)

map_CP.add_child(mc)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
len(dfz['Coords_Latitude'].unique())
len(dfz['Coords_Longitude'].unique())
# Out:
# 88604

# %%
def getDist(long1,lat1,long2,lat2):
    return np.sqrt((long1-long2)**2 + (lat1-lat2)**2)

def getClosestStation(row,dfStations):
    long = row['Coords_Longitude']
    lat = row['Coords_Latitude']
    shortestDist = sys.float_info.max
    for i in range (0,len(dfStations.index)):
        d = getDist(long,lat,dfStations.iloc[i].Longitude,dfStations.iloc[i].Latitude)
        if (d < shortestDist): 
            shortestDist = d
            longF = dfStations.iloc[i].Longitude
            latF = dfStations.iloc[i].Latitude
            stationName = dfStations.iloc[i].Name
    return pd.Series([latF,longF, stationName])

# %%
import sys
import numpy as np
dfStations = pd.read_csv('../data/stationsInfo.csv')
df_withStation = dfz.iloc[:1000].copy()

print(len(df_withStation.index))
df_withStation['StationName'] = None
df_withStation[['Coords_Latitude','Coords_Longitude','StationName']] = df_withStation.apply(getClosestStation,args=(dfStations,), axis=1)

df_withStation
# Out:
# 1000
#        Coords_Latitude  Coords_Longitude            Trip_ID  \
# 0            38.978129        -76.929079  Hf3aj78RcGaJJMGRn
# 1            38.978129        -76.929079  tp7QKuiJX9DvLKDcf
# 2            38.972794        -76.938213  tp7QKuiJX9DvLKDcf
# 3            38.978129        -76.929079  j7xEWoy65rDsJfk7M
# 4            38.972794        -76.938213  j7xEWoy65rDsJfk7M
# 5            38.972794        -76.938213  YsPoSKbfooMuwpfTR
# 6            38.978129        -76.929079  YsPoSKbfooMuwpfTR
# 7            38.978129        -76.929079  s4RaLMLAmbQ6kQDkw
# 8            38.972794        -76.938213  s4RaLMLAmbQ6kQDkw
# 9            38.978129        -76.929079  neK2FmGgoafPrems7
# 10           38.972794        -76.938213  neK2FmGgoafPrems7
# 11           38.978129        -76.929079  wLxfjzdvaGAGHi6sZ
# 12           38.972794        -76.938213  wLxfjzdvaGAGHi6sZ
# 13           38.972794        -76.938213  uL6QHMpuYzwugePus
# 14           38.978129        -76.929079  uL6QHMpuYzwugePus
# 15           38.978129        -76.929079  uT8KehQKxxandkxZo
# 16           38.992959        -76.933312  22LyFxToajiYQJQD3
# 17           38.992959        -76.933312  22LyFxToajiYQJQD3
# 18           38.984549        -76.948848  HWwe7XQvERwKStssc
# 72           38.993316        -76.946189  HWwe7XQvERwKStssc
# 73           38.993316        -76.946189  PrCBctt2qpcLsyvjk
# 96           38.984549        -76.948848  PrCBctt2qpcLsyvjk
# 97           38.993316        -76.946189  D4A3ko2g6k9f6KRts
# 115          38.981365        -76.937776  D4A3ko2g6k9f6KRts
# 116          38.993316        -76.946189  A76f7XBPTGPHkytJg
# 126          38.984549        -76.948848  A76f7XBPTGPHkytJg
# 127          38.993316        -76.946189  2RhuGvrsi3xngG5rX
# 133          38.984549        -76.948848  2RhuGvrsi3xngG5rX
# 134          38.993316        -76.946189  4AXmsjP43Q9TFS9DT
# 202          38.993316        -76.946189  SCkuaGqdbGDzA5Mep
# ...                ...               ...                ...
# 15168        38.982425        -76.943613  Fsf3KnSRr7TPwnmr2
# 15181        38.982425        -76.943613  SQYXeRQoBwsktw9SL
# 15183        38.982425        -76.943613  JNbcZ6LeWoQWzXpxH
# 15197        38.985199        -76.942699  HacCmByL3xj9oPbnD
# 15207        38.982425        -76.943613  FkfnNJ8DPgZ9jTPsa
# 15248        38.993316        -76.946189  FkfnNJ8DPgZ9jTPsa
# 15249        38.993316        -76.946189  citpXoNeeNvfEFGau
# 15289        38.982425        -76.943613  citpXoNeeNvfEFGau
# 15291        38.993316        -76.946189  4ykSt3nXg6yo9dmw5
# 15327        38.982425        -76.943613  4ykSt3nXg6yo9dmw5
# 15328        38.993316        -76.946189  CoBZBFHd5xunb6q7z
# 15331        38.993316        -76.946189  u7HFsZrmWnsknXFnN
# 15332        38.993316        -76.946189  X25EYrn2Ha2iLaFPy
# 15335        38.982425        -76.943613  spfxFGdoWzasFw4Cx
# 15337        38.982425        -76.943613  SmeMHWRtvmvefQ4Du
# 15339        38.982425        -76.943613  v7F9WEKyAbHjz9XhR
# 15340        38.989979        -76.940757  dGfYCSJBAJaQ6SxrH
# 15343        38.982425        -76.943613  hR5mzHj67rqALDAmr
# 15348        38.982425        -76.943613  ESXMrCw6Ty7yaykS3
# 15416        38.993316        -76.946189  ESXMrCw6Ty7yaykS3
# 15418        38.993316        -76.946189  nt49P2puXgY6zC9hz
# 15420        38.982425        -76.943613  WDbuHuhok7jjdJwu9
# 15421        38.993316        -76.946189  wpzMJYnpytQiTxEH8
# 15424        38.993316        -76.946189  mgTwHALAjEknmGrLx
# 15426        38.982425        -76.943613  ohpcmJibr2pPcdNH5
# 15428        38.982425        -76.943613  NnDANYsKkCAWPyzwD
# 15429        38.989979        -76.940757  X4B2tavSoQgQ3iPGd
# 15431        38.993316        -76.946189  3g8t7jKwD4JfbB2vh
# 15433        38.989979        -76.940757  der462gvtYerCpmPM
# 15435        38.982425        -76.943613  KcKAGLdPLPJW9RnxM
#
#                   Bike_Event                   User_ID  \
# 0                  StartTrip         24Tswou857XKT9R65
# 1                  StartTrip         24Tswou857XKT9R65
# 2      EndTripInsideGeofence         24Tswou857XKT9R65
# 3                  StartTrip         24Tswou857XKT9R65
# 4      EndTripInsideGeofence         24Tswou857XKT9R65
# 5                  StartTrip         24Tswou857XKT9R65
# 6      EndTripInsideGeofence         24Tswou857XKT9R65
# 7                  StartTrip         24Tswou857XKT9R65
# 8      EndTripInsideGeofence         24Tswou857XKT9R65
# 9                  StartTrip         24Tswou857XKT9R65
# 10     EndTripInsideGeofence         24Tswou857XKT9R65
# 11                 StartTrip         24Tswou857XKT9R65
# 12     EndTripInsideGeofence         24Tswou857XKT9R65
# 13                 StartTrip         24Tswou857XKT9R65
# 14     EndTripInsideGeofence         24Tswou857XKT9R65
# 15                 StartTrip         24Tswou857XKT9R65
# 16                 StartTrip  25s4sMQh46Stf2zgQtJ9Tpxw
# 17     EndTripInsideGeofence  25s4sMQh46Stf2zgQtJ9Tpxw
# 18                 StartTrip  26qA87mpcaQQhG37beEnELBw
# 72     EndTripInsideGeofence  26qA87mpcaQQhG37beEnELBw
# 73                 StartTrip  26qA87mpcaQQhG37beEnELBw
# 96     EndTripInsideGeofence  26qA87mpcaQQhG37beEnELBw
# 97                 StartTrip  26qA87mpcaQQhG37beEnELBw
# 115    EndTripInsideGeofence  26qA87mpcaQQhG37beEnELBw
# 116                StartTrip  26qA87mpcaQQhG37beEnELBw
# 126    EndTripInsideGeofence  26qA87mpcaQQhG37beEnELBw
# 127                StartTrip  26qA87mpcaQQhG37beEnELBw
# 133    EndTripInsideGeofence  26qA87mpcaQQhG37beEnELBw
# 134                StartTrip  26qA87mpcaQQhG37beEnELBw
# 202                StartTrip  26qA87mpcaQQhG37beEnELBw
# ...                      ...                       ...
# 15168              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15181              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15183              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15197              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15207              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15248  EndTripInsideGeofence  2JStBqQQecWeZNfibveXMo8w
# 15249              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15289  EndTripInsideGeofence  2JStBqQQecWeZNfibveXMo8w
# 15291              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15327  EndTripInsideGeofence  2JStBqQQecWeZNfibveXMo8w
# 15328              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15331              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15332              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15335              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15337              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15339              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15340              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15343              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15348              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15416  EndTripInsideGeofence  2JStBqQQecWeZNfibveXMo8w
# 15418              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15420              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15421              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15424              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15426              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15428              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15429              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15431              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15433              StartTrip  2JStBqQQecWeZNfibveXMo8w
# 15435              StartTrip  2JStBqQQecWeZNfibveXMo8w
#
#                       Date_Time               StationName
# 0      2017-06-14T19:02:21.593Z   College Park Metro West
# 1      2017-06-15T20:07:14.437Z   College Park Metro West
# 2      2017-06-15T20:19:43.891Z             Queens Chapel
# 3      2017-06-17T22:25:55.592Z   College Park Metro West
# 4      2017-06-17T22:36:07.021Z             Queens Chapel
# 5      2017-06-22T11:09:32.494Z             Queens Chapel
# 6      2017-06-22T11:15:14.979Z   College Park Metro West
# 7      2017-06-22T17:10:02.014Z   College Park Metro West
# 8      2017-06-22T17:19:45.178Z             Queens Chapel
# 9      2017-06-23T19:10:43.815Z   College Park Metro West
# 10     2017-06-23T19:20:30.796Z             Queens Chapel
# 11     2017-06-24T19:21:27.136Z   College Park Metro West
# 12     2017-06-26T18:11:27.749Z             Queens Chapel
# 13     2017-06-26T18:11:52.624Z             Queens Chapel
# 14     2017-06-26T18:18:50.277Z   College Park Metro West
# 15     2017-06-27T01:06:33.425Z   College Park Metro West
# 16     2017-07-09T22:20:13.969Z           University View
# 17     2017-07-10T01:23:43.831Z           University View
# 18     2017-08-30T14:44:01.107Z               Mowatt Lane
# 72     2017-08-30T14:52:59.533Z                    Eppley
# 73     2017-09-06T13:15:31.577Z                    Eppley
# 96     2017-09-06T13:24:38.741Z               Mowatt Lane
# 97     2017-09-18T16:20:38.292Z                    Eppley
# 115    2017-09-18T16:52:10.964Z                 City Hall
# 116    2017-09-20T13:22:42.354Z                    Eppley
# 126    2017-09-20T13:29:47.986Z               Mowatt Lane
# 127    2017-09-25T13:22:48.663Z                    Eppley
# 133    2017-09-25T13:29:28.612Z               Mowatt Lane
# 134    2017-10-30T13:25:39.574Z                    Eppley
# 202    2017-11-08T14:19:33.931Z                    Eppley
# ...                         ...                       ...
# 15168  2018-06-19T22:46:40.090Z  South Campus Dining Hall
# 15181  2018-06-20T00:00:52.906Z  South Campus Dining Hall
# 15183  2018-06-20T00:01:33.843Z  South Campus Dining Hall
# 15197  2018-06-20T12:57:03.675Z             McKeldin Mall
# 15207  2018-06-20T13:08:46.574Z  South Campus Dining Hall
# 15248  2018-06-20T13:16:05.088Z                    Eppley
# 15249  2018-06-20T14:26:04.121Z                    Eppley
# 15289  2018-06-20T14:32:37.318Z  South Campus Dining Hall
# 15291  2018-06-22T14:41:28.466Z                    Eppley
# 15327  2018-06-22T14:46:59.353Z  South Campus Dining Hall
# 15328  2018-06-25T14:09:11.044Z                    Eppley
# 15331  2018-06-26T14:37:17.629Z                    Eppley
# 15332  2018-06-26T14:38:01.512Z                    Eppley
# 15335  2018-06-27T14:06:21.776Z  South Campus Dining Hall
# 15337  2018-06-28T14:27:31.554Z  South Campus Dining Hall
# 15339  2018-06-28T14:28:47.978Z  South Campus Dining Hall
# 15340  2018-06-29T13:54:45.673Z             Regents Drive
# 15343  2018-07-02T13:37:00.380Z  South Campus Dining Hall
# 15348  2018-07-02T13:43:52.944Z  South Campus Dining Hall
# 15416  2018-07-02T13:51:09.352Z                    Eppley
# 15418  2018-07-02T14:43:45.860Z                    Eppley
# 15420  2018-07-03T13:32:02.237Z  South Campus Dining Hall
# 15421  2018-07-05T14:09:46.614Z                    Eppley
# 15424  2018-07-11T14:23:31.189Z                    Eppley
# 15426  2018-07-12T12:36:02.394Z  South Campus Dining Hall
# 15428  2018-07-13T14:09:29.411Z  South Campus Dining Hall
# 15429  2018-07-16T14:54:23.571Z             Regents Drive
# 15431  2018-07-18T14:55:51.335Z                    Eppley
# 15433  2018-07-19T13:59:54.133Z             Regents Drive
# 15435  2018-07-23T20:26:38.666Z  South Campus Dining Hall
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Estimating coverage of the 24 mBike stations
# **We assume that people are willing to walk 1/4 mile.**

# %%
dfStations
m = folium.Map(location=[dfStations['Latitude'].mean(),dfStations['Longitude'].mean()], zoom_start=14)

# Red will mean more bikes ended than started, Blue means more started than ended
for i in range(0,len(dfStations)):
    #net_norm = dfStations.iloc[i]['Diff_Norm']
    #if (net_norm>0): 
    #    c ='crimson'
    #else: 
     #   c = 'blue' 

    folium.Circle(
      location=[dfStations.iloc[i]['Latitude'], dfStations.iloc[i]['Longitude']],
      #popup=dfmergeSE.iloc[i]['Name'],
      radius=402,#402, #1/4 mile
      color='blue',
        opacity=0.3,
   ).add_to(m)
m
m.save('stationCoverage.html')
